# %% [markdown]
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:50px;font-family:Georgia;text-align:center;">👨‍💻<strong>House Prices<strong style="color:#00bfff;font-size:47px;font-family:Georgia;"> - <strong style="color:black;font-size:50px;font-family:Georgia;">Advanced Regression </strong></strong></strong>👨‍💻</h1>
#
# <p style= "font-family:Georgia;color:#000000;font-size:110%;text-align:center;">This Notebook will be beginner friendly. It provides a clear step by step guide on data wrangling,also know as data cleaning or data preprocessing, and exploratory data analysis. After going though this notebook one will have ready formatted data for modelling. So lets 🏊‍♂️ into context.<br>
#
# <p style= "font-family:Georgia;color:#006400;font-size:110%;text-align:center;">Give an UPVOTE to let me know how usefull this notebook was. Should have any questions feel free to write in comment section<br>
#
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
#
#
# <h1 style="color:black;font-size:40px;font-family:Georgia;text-align:center;">👨‍💻<strong>Problem Statement</strong>👨‍💻</h1>
# <p style= "font-family:Georgia;color:#000000;font-size:110%;text-align:center;">Data cleaning is a crucial step in the process of building efficient machine learning models. It involves identifying and correcting errors, inconsistencies, and inaccuracies in the dataset before using it to train a model.</p>
#
# <p style= "font-family:Georgia;color:#000000;font-size:110%;text-align:center;">🔴Some reasons why data cleaning is so important for obtaining efficient models:</p>
#
# <p style= "font-family:Georgia;color:#9400d3;font-size:110%;text-align:center;">1️⃣Garbage in and garbage out,<span class="spacer"></span>   2️⃣Improved model accuracy,<span class="spacer"></span>   3️⃣Reducing overfitting,<span class="spacer"></span>   4️⃣Consistency and compatibility,<span class="spacer"></span>   5️⃣Time and cost efficiency,<span class="spacer"></span>   6️⃣Improved interpretability,<span class="spacer"></span>   7️⃣Better feature engineering,<span class="spacer"></span>   8️⃣Enhanced data visualization.</p>
#
#
# <p style= "font-family:Georgia;color:#000000;font-size:110%;text-align:center;">In summary,Housing Data Contiaing 79 Attributes with lot of missing values and outliers, .: Data cleaning is essential for obtaining efficient models because it ensures that the model learns from reliable and relevant information, leading to better performance, generalization, and interpretability. It is a critical step that should not be overlooked in the machine learning pipeline.</p>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
#
# <h1 style="color:black;font-size:40px;font-family:Georgia;text-align:center;">👨‍💻<strong>About DataSet </strong>👨‍💻</h1>
# <center><a href="https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data">Click here to know about data set</a></center> </p>
#
#
#
#
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:40px;font-family:Georgia;text-align:center;">👨‍💻<strong>Table <strong style="color:#00bfff;font-size:37px;font-family:Georgia;">of <strong style="color:black;font-size:40px;font-family:Georgia;">the <strong style="color:#00bfff;font-size:37px;font-family:Georgia;">Contents</strong></strong></strong></strong>👨‍💻</h1>
#
# * [An Overview.](#1)
# * [Importing Libraries.](#2)
# * [Loading & Reading The Dataset.](#3)
# * [Data Exploration.](#4)
# * [Data Preprocessing.](#5)
# * [Exploratory Data Analysis.](#6)
# * [Links to other notebooks.](#7)

# %% [markdown]
# <a id="1"></a>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong> AN OVER<strong style="color:black;font-size:32px;font-family:Georgia;">VIEW</strong></strong></strong>👨‍💻</h1>

# %% [markdown]
# ![workfow.jpg](attachment:f53b4c7d-a142-4878-adfd-a74806fab1cd.jpg)

# %% [markdown]
# <a id="2"></a>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong>IMPORTING <strong style="color:#00bfff;font-size:32px;font-family:Georgia;">THE <strong style="color:black;font-size:32px;font-family:Georgia;">LIBRARIES</strong></strong></strong>👨‍💻</h1>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # all_data processing, CSV file I/O (e.g. pd.read_csv)

# Input all_data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv

# %%
#Import some necessary librairies

import numpy as np 
import pandas as pd 
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats
from scipy.stats import norm, skew



#To ignore warnings
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn 
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.filterwarnings("ignore")
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# <a id="3"></a>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong>READING<strong style="color:#00bfff;font-size:30px;font-family:Georgia;">THE <strong style="color:black;font-size:32px;font-family:Georgia;">FILE</strong></strong></strong>👨‍💻</h1>

# %%
train = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
test = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')

# %%
# Combining Train and Test data to make preprocessing easier and efficient
ntrain = train.shape[0]
ntest = test.shape[0]
test_id = test["Id"]
y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (2919, 80)

# %%
#Dropping ID Features from both Train and Test Data Set
all_data.drop("Id",axis=1,inplace=True)
all_data.shape
# Out:
# (2919, 79)

# %% [markdown]
# <a id="4"></a>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong>DATA <strong style="color:black;font-size:32px;font-family:Georgia;">EXPLORATION</strong></strong>👨‍💻</h1>

# %%
#Exploring Trian Data
def data_explore(df):
    print("Shape of Dataset".center(125,"-"))
    print("Rows:{}".format(df.shape[0]))
    print("Columns:{}".format(df.shape[1]))
    print("Data Head".center(125,"-"))
    print(df.head(5))
    print("Data Types".center(125,"-"))
    print(df.dtypes.value_counts())
    print("Duplicates".center(125,"-"))
    print(df.duplicated().sum())
    print("Missing Values".center(125,"-"))
    print(df.isnull().sum().sort_values(ascending=False))
data_explore(all_data)
# Out:
# -------------------------------------------------------Shape of Dataset------------------------------------------------------
# Rows:2919
# Columns:79
# ----------------------------------------------------------Data Head----------------------------------------------------------
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL       65.000     8450   Pave   NaN      Reg
# 1          20       RL       80.000     9600   Pave   NaN      Reg
# 2          60       RL       68.000    11250   Pave   NaN      IR1
# 3          70       RL       60.000     9550   Pave   NaN      IR1
# 4          60       RL       84.000    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# ...

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
#
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong>Point to be noted</strong>👨‍💻</h1>
# <li>Data Set has missing values need to be dealt
# <li>Categorical variables has high cordinality which needs to be encoded
# <li>Numerical Continious Varibales has very high deviation which may lead to noice and reduce model accurancy
# </div>
# </div>

# %% [markdown]
# <a id="5"></a>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong>DATA <strong style="color:black;font-size:32px;font-family:Georgia;">PRE-PROCESSING</strong></strong>👨‍💻</h1>

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
# SalePrice is a target variable which has to be predicted. Hence this variable need to be Normalized.
# </div>
# </div>

# %%
#Check the distribution 
sns.distplot(y_train , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(y_train)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')

fig = plt.figure()
res = stats.probplot(y_train, plot=plt,sparams=(2.5,))
plt.show()
# Out:
#  mu = 180921.20 and sigma = 79415.29

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
# The Taget varibale are clearly right skewed which effect the linear models.
# </div>
# </div>

# %%
#Applying Log
y_train = np.log1p(y_train)

# %%
#Check the new distribution 
sns.distplot(y_train , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(y_train)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')

fig = plt.figure()
res = stats.probplot(y_train, plot=plt,sparams=(2.5,))
plt.show()
# Out:
#  mu = 12.02 and sigma = 0.40

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
# Now Target variable appears normally distributed.
# </div>
# </div>

# %% [markdown]
# <a id="6"></a>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong>EXPLORATORY <strong style="color:#00bfff;font-size:30px;font-family:Georgia;">DATA<strong style="color:black;font-size:32px;font-family:Georgia;"> ANALYSIS</strong></strong></strong>👨‍💻</h1>

# %% [markdown]
# ## 1️⃣ Missing Values

# %%
#Checking the columns with NaN's
all_data.isnull().sum()[all_data.isnull().sum()>0].sort_values(ascending=False)
# Out:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# FireplaceQu     1420
# LotFrontage      486
# GarageFinish     159
# GarageQual       159
# GarageCond       159
# GarageYrBlt      159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MasVnrArea        23
# MSZoning           4
# BsmtFullBath       2
# BsmtHalfBath       2
# Functional         2
# Utilities          2
# GarageArea         1
# GarageCars         1
# Electrical         1
# KitchenQual        1
# TotalBsmtSF        1
# BsmtUnfSF          1
# BsmtFinSF2         1
# BsmtFinSF1         1
# Exterior2nd        1
# Exterior1st        1
# SaleType           1
# dtype: int64

# %%
print("No. of columns containing null values")
print(len(all_data.columns[all_data.isnull().any()]))

print("No. of columns not containing null values")
print(len(all_data.columns[all_data.notnull().all()]))

print("Total no. of columns in the dataframe")
print(len(all_data.columns))
# Out:
# No. of columns containing null values
# 34
# No. of columns not containing null values
# 45
# Total no. of columns in the dataframe
# 79

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
#     Lets uncover all <b>34</b> columns which contain NaN's and anticipate accoring to the decription given in data file.
# </div>
# </div>

# %% [markdown]
# **1. PoolQC with 2909 missig values**
# > NaN in PoolQC describe there is no pool for the house .: NA = No Pool (Np)

# %%
all_data["PoolQC"] = all_data["PoolQC"].replace(np.nan,"None")
all_data["PoolQC"].value_counts()
# Out:
# None    2909
# Ex         4
# Gd         4
# Fa         2
# Name: PoolQC, dtype: int64

# %% [markdown]
# **2.MiscFeature with 2814 missig values**
# > NaN in MiscFeature describe there is no Miscellaneous feature for the house .: NA = None

# %%
all_data["MiscFeature"] = all_data["MiscFeature"].replace(np.nan,"None")
all_data["MiscFeature"].value_counts()
# Out:
# None    2814
# Shed      95
# Gar2       5
# Othr       4
# TenC       1
# Name: MiscFeature, dtype: int64

# %% [markdown]
# **3. Alley with 2721 missig values**
# > NaN in Alley describe there is No alley access for the house .: NA = None

# %%
all_data["Alley"] = all_data["Alley"].replace(np.nan,"None")
all_data["Alley"].value_counts()
# Out:
# None    2721
# Grvl     120
# Pave      78
# Name: Alley, dtype: int64

# %% [markdown]
# **4. Fence with 2348 missig values**
# > NaN in Alley describe there is No Fence for the house .: NA = None

# %%
all_data["Fence"] = all_data["Fence"].fillna("None")

# %% [markdown]
# **5. FireplaceQu : all_data description says NA means "no fireplace"**

# %%
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")

# %% [markdown]
# **6. LotFrontage : Since the area of each street connected to the house property most likely have a similar area to other houses in its neighborhood , we can fill in missing values by the median LotFrontage of the neighborhood.**

# %%
#Group by neighborhood and fill in missing value by the median LotFrontage of all the neighborhood
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))

# %% [markdown]
# **7,8,9,10. GarageType, GarageFinish, GarageQual and GarageCond : Replacing missing all_data with None**

# %%
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')

# %% [markdown]
# **11,12,13. GarageYrBlt, GarageArea and GarageCars : Replacing missing data with 0 (Since No garage = no cars in such garage.)**

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# **14,15,16,17,18,19. BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, BsmtFullBath and BsmtHalfBath : missing values are likely zero for having no basement**

# %%
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# **20,21,22,23,24. BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1 and BsmtFinType2 : For all these categorical basement-related features, NaN means that there is no basement.**

# %%
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')

# %% [markdown]
# **25,26. MasVnrArea and MasVnrType : NA most likely means no masonry veneer for these houses. We can fill 0 for the area and None for the type.**

# %%
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)

# %% [markdown]
# **27. MSZoning (The general zoning classification) : 'RL' is by far the most common value. So we can fill in missing values with 'RL'**

# %%
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])

# %% [markdown]
# **28. Utilities : For this categorical feature all records are "AllPub", except for one "NoSeWa" and 2 NA . Since the house with 'NoSewa' is in the training set, this feature won't help in predictive modelling. We can then safely remove it.**

# %%
all_data = all_data.drop(['Utilities'], axis=1)

# %% [markdown]
# **29.Functional : data description says NA means typical**

# %%
all_data["Functional"] = all_data["Functional"].fillna("Typ")

# %% [markdown]
# **30.Electrical : It has one NA value. Since this feature has mostly 'SBrkr', we can set that for the missing value.**

# %%
all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])

# %% [markdown]
# **31.KitchenQual: Only one NA value, and same as Electrical, we set 'TA' (which is the most frequent) for the missing value in KitchenQual.**

# %%
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])

# %% [markdown]
# **32. Exterior1st and Exterior2nd : Again Both Exterior 1 & 2 have only one missing value. We will just substitute in the most common string**

# %%
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])

# %% [markdown]
# **33. SaleType : Fill in again with most frequent which is "WD"**

# %%
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])

# %% [markdown]
# **34.MSSubClass : Na most likely means No building class. We can replace missing values with None**

# %%
all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

# %%
print("The total number of missing values from data frame after cleaning:",all_data.isnull().sum().sum())
# Out:
# The total number of missing values from data frame after cleaning: 0

# %% [markdown]
# ## 2️⃣ Standardization and Formatting

# %%
#lets check data types
pd.set_option('display.max_columns', None)
all_data.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 78, dtype: object

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
# Transforming some numerical variables that are really categorical
# </div>
# </div>

# %%
#MSSubClass=The building class
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)


#Changing OverallCond into a categorical variable
all_data['OverallCond'] = all_data['OverallCond'].astype(str)


#Year and month sold are transformed into categorical features.
all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %% [markdown]
# ## 3️⃣ Lable Encoding

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
# Label Encoding some categorical variables that may contain information in their ordering set.
# </div>
# </div>

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')
# process columns, apply LabelEncoder to categorical features
for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[c].values)) 
    all_data[c] = lbl.transform(list(all_data[c].values))

# shape        
print('Shape all_data: {}'.format(all_data.shape))
# Out:
# Shape all_data: (2919, 78)

# %% [markdown]
# ## 4️⃣ Feature Engineering

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:25px">
# As area is higly correlated to the SalesPrice, Lets add all the area and engineer new variable of its sum.
# </div>
# </div>

# %%
# Adding total sqfootage feature 
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %% [markdown]
# ## 5️⃣ Normalization

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

# Check the skew of all numerical features
skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(10)
# Out:
# Skew in numerical features:
#                 Skew
# MiscVal       21.947
# PoolArea      16.898
# LotArea       12.822
# LowQualFinSF  12.089
# 3SsnPorch     11.376
# LandSlope      4.975
# KitchenAbvGr   4.302
# BsmtFinSF2     4.146
# EnclosedPorch  4.004
# ScreenPorch    3.947

# %%
skewness = skewness[abs(skewness) > 0.75]
skewed_features = all_data[skewness.index]
for col in skewed_features:
    all_data[col] = np.log1p(all_data[col])

# %% [markdown]
# ## 6️⃣ One Hot Coding

# %%
all_data = pd.get_dummies(all_data)
print(all_data.shape)
# Out:
# (2919, 221)

# %%
#Splitting train and test test back
train = all_data[:ntrain]
test = all_data[ntrain:]
print("Shape of train data:",train.shape)
print("Shape of test data:",test.shape)
# Out:
# Shape of train data: (1460, 221)
# Shape of test data: (1459, 221)

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#9400d3'; padding:30px; font-size:25px">
#     Now Data is ready for Modelling. If you find this Kernel usefull then dont forget to UPVOTE. Happy Kaggling✌
# </div>
# </div>

# %% [markdown]
# <a id="7"></a>
# <p style="background-color:#00bfff;font-family:Georgia;color:#00bfff;font-size:105%;text-align:center;border-radius:10px 10px;border-style: dotted;border-width:17px;border-color:#00bfff;"></p>
# <h1 style="color:black;font-size:32px;font-family:Georgia;text-align:center;">👨‍💻<strong>My<strong style="color:#00bfff;font-size:30px;font-family:Georgia;"> other<strong style="color:black;font-size:32px;font-family:Georgia;"> Notebooks</strong></strong></strong>👨‍💻</h1>

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 10px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#9400d3'; padding:30px; font-size:25px">
#     <p style= "font-family:Georgia;color:#000000;font-size:110%;text-align:center;">
# <a href="https://www.kaggle.com/code/adarshcgowda/new-rfmt-model-for-segmentation-1st-in-kaggle"> https://www.kaggle.com/code/adarshcgowda/new-rfmt-model-for-segmentation-1st-in-kaggle </a><br>
# <a href="https://www.kaggle.com/code/adarshcgowda/simplified-segmentation-rfm-kmeans"> https://www.kaggle.com/code/adarshcgowda/simplified-segmentation-rfm-kmeans </a><br>
# <a href="https://www.kaggle.com/code/adarshcgowda/car-used-price-prediction-95-accuracy"> https://www.kaggle.com/code/adarshcgowda/car-used-price-prediction-95-accuracy </a><br>
# <a href="https://www.kaggle.com/code/adarshcgowda/enjoy-learn-titanic-survival-beginner-guide"> https://www.kaggle.com/code/adarshcgowda/enjoy-learn-titanic-survival-beginner-guide </a><br>
#
#
# </div>
# </div>
